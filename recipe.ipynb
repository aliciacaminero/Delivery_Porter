# %%
import pandas as pd

# %%
data_recipe = pd.read_csv('data_recipe.csv')
data_recipe.head()
# Out:
#   Recipe_ID          Recipe_Name Cuisine_Type Ingredients_List_0  \
# 0      R001           Beef Tacos      Mexican               Beef
# 1      R002  Spaghetti Bolognese      Italian          Spaghetti
# 2      R003        Chicken Curry       Indian            Chicken
# 3      R004        Chicken Curry       Indian            Chicken
# 4      R005   Vegetable Stir Fry      Chinese           Broccoli
#
#   Ingredients_List_1 Ingredients_List_2 Ingredients_List_3 Ingredients_List_4  \
# 0        Taco Shells            Lettuce             Cheese             Tomato
# 1        Ground Beef       Tomato Sauce              Onion             Garlic
# 2       Curry Powder       Coconut Milk              Onion             Garlic
# 3       Curry Powder       Coconut Milk              Onion             Garlic
# 4             Carrot        Bell Pepper          Soy Sauce             Garlic
#
#   Preparation_Steps_0_0 Preparation_Steps_0_1  ... User_Feedback  \
# ...

# %%
data_recipe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Recipe_ID              5000 non-null   object
#  1   Recipe_Name            5000 non-null   object
#  2   Cuisine_Type           5000 non-null   object
#  3   Ingredients_List_0     5000 non-null   object
#  4   Ingredients_List_1     5000 non-null   object
#  5   Ingredients_List_2     5000 non-null   object
#  6   Ingredients_List_3     5000 non-null   object
#  7   Ingredients_List_4     5000 non-null   object
#  8   Preparation_Steps_0_0  5000 non-null   object
#  9   Preparation_Steps_0_1  5000 non-null   object
#  10  Preparation_Steps_0_2  5000 non-null   object
#  11  Preparation_Steps_0_3  2978 non-null   object
#  12  Cooking_Time_Minutes   5000 non-null   int64
#  13  Difficulty_Level       5000 non-null   object
# ...

# %%
data_recipe.isnull().sum()
# Out:
# Recipe_ID                   0
# Recipe_Name                 0
# Cuisine_Type                0
# Ingredients_List_0          0
# Ingredients_List_1          0
# Ingredients_List_2          0
# Ingredients_List_3          0
# Ingredients_List_4          0
# Preparation_Steps_0_0       0
# Preparation_Steps_0_1       0
# Preparation_Steps_0_2       0
# Preparation_Steps_0_3    2022
# Cooking_Time_Minutes        0
# Difficulty_Level            0
# User_ID                     0
# User_Preferences         2003
# User_Rating                 0
# User_Feedback               0
# Date_Prepared               0
# Season                      0
# Occasion                    0
# Serving_Size                0
# Calories_Per_Serving        0
# Allergen_Information     1948
# Cost_Per_Serving            0
# Popularity_Score            0
# Seasonal_Availability       0
# dtype: int64

# %%
data_recipe
